# %% [markdown]
# Operações matemáticas

# %%
10+14
# Out:
# 24

# %%
10-5
# Out:
# 5

# %%
10/3
# Out:
# 3.3333333333333335

# %%
10%3
# Out:
# 1

# %%
10**3
# Out:
# 1000

# %% [markdown]
# Variáveis

# %%
salario = 10000
salario * 2
# Out:
# 20000

# %%
pi = 3.1415

# %%
nome = "Anna"

# %%
conta_maluca = salario ** 1/2 + pi * (salario/2)
conta_maluca
# Out:
# 20707.5

# %% [markdown]
# Funções

# %%
def ola_mundo():
    print('olá mundo!')

# %%
ola_mundo()
# Out:
# olá mundo!

# %%
def salario_liquido(salario, ir):
    salario_bruto = salario
    salario_liquido = salario_bruto * (1-ir)
    return salario_liquido

# %%
salario_liquido(2000, 0.1)
# Out:
# 1800.0
